# %%
# Import necessary modules for Google Colab and Gemini API integration
from google.colab import userdata
userdata.get('GEMINI_API_KEY') # Retrieve the Gemini API Key securely
# Out:
# 'AIzaSyCpN1DSJegqmeF79dZ5JzAr_KRLzCUWgw0'

# %%
# Install the google-generativeai library for using Gemini API
# !pip install -U google-generativeai

# %%
# Import the library after installation
import google.generativeai as genai

# %%
# Configure the Gemini API with the provided API key
genai.configure(api_key="AIzaSyCpN1DSJegqmeF79dZ5JzAr_KRLzCUWgw0")

# %%
# Initialize the generative model (e.g., gemini-1.5-flash)
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
# Import additional libraries for handling image input
import requests
from io import BytesIO
from PIL import Image
from IPython.display import display

url = ("https://th.bing.com/th/id/R.a83bc096189d4c1cd7886c837eafced2?rik=1qbkqO%2bo6eHafA&pid=ImgRaw&r=0")
response = requests.get(url)
img = Image.open(BytesIO(response.content))
display(img)

# %%
# Define the image URL (replace with your desired image link)
# !curl -o image.jpg "https://th.bing.com/th/id/R.a83bc096189d4c1cd7886c837eafced2?rik=1qbkqO%2bo6eHafA&pid=ImgRaw&r=0"

# %%
# Define the prompt to provide context for the model
prompt = "explain the image"
# Generate content using the Gemini API with the image and the prompt
response1 = model.generate_content([img,prompt])
# Print the response generated by the model
print(response1.text)
